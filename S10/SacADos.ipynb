# %% [markdown]
# # Problème du sac à dos

# %% [markdown]
# On cherche à remplir un sac à dos en emportant les objets dont la valeur totale sera maximale, en respectant une contrainte : le sac à dos ne peut pas porter plus de 10kg.

# %%
objlist = [('Antidote', 3, 0.5), 
           ('Baguette magique', 5,1), 
           ('Cape d\'invisibilité', 12,1), 
           ('Diadème', 30,5), 
           ('Épée', 9,6), 
           ('Horloge', 10,5), 
           ('Miroir', 12,3)]
POIDS_MAX=10

# %% [markdown]
# Compléter le code de chacune des trois fonctions.

# %%
def nom(objet):
    return objet[...]

def valeur(objet):
    return objet[...]

def masse(objet):
    return objet[...]

for x in objlist : 
    print(nom(x), valeur(x), masse(x))

# %% [markdown]
# ### I. Choix des objets  : dans l'ordre alphabétique

# %% [markdown]
# #### Compléter le code suivant
# Il réalise le choix des objets en suivant l'ordre du tableau

# %%
def glouton(liste_obj):
    sac = []
    masse_du_sac = 0
    valeur_du_sac = 0
    for x in liste_obj:
        if ...  :
            sac.append(x)
            
            
    print('valeur du sac : ', valeur_du_sac)
    print('masse du sac : ', masse_du_sac)
    return sac

# %%
glouton(objlist)

# %% [markdown]
# ### II. Choix des objets : les plus précieux d'abord

# %% [markdown]
# Pour améliorer le choix des objets, on va commencer par trier la liste d'objets.
# On commence par privilégier les objets les plus précieux.
#
# Compléter la fonction `glouton_par_valeur` pour qu'elle effectue le tri d'une liste d'objets en les classant du plus précieux au moins précieux, puis suive le même algorithme glouton que précédemment.

# %%
help(sorted)

# %%
def glouton_par_valeur(t):
    ...

# %%
glouton_par_valeur(...)

# %% [markdown]
# ### III. Choix des objets avec un autre critère

# %% [markdown]
# Compléter la définition de la fonction `valeur_massique`, qui renvoie la valeur massique de l'objet `x` passé en argument.

# %%
def valeur_massique(x):
    return valeur(x) / masse(x)

# %% [markdown]
# - Compléter le code de la fonction glouton_avec_critere , qui trie le tableau en utilisant une fonction `critere`

# %%
def glouton_avec_critere(t , critere):
    liste_tri = sorted(t, key = critere, reverse = True) 
    return glouton(liste_tri)

# %% [markdown]
# - Utiliser cette fonction pour exécuter l'algorithme glouton sur le sac à dos, en privilégiant les objets de grande valeur massique

# %%
glouton_avec_critere(...)

# %% [markdown]
# ## Comparaison
# En modifiant la masse maximale du sac, comparer l'efficacité des différentes stratégies

# %%
objlist = [('Antidote', 3, 0.5), 
           ('Baguette magique', 5,1), 
           ('Cape d\'invisibilité', 12,1), 
           ('Diadème', 30,5), 
           ('Épée', 9,6), 
           ('Horloge', 10,5), 
           ('Miroir', 12,3)]
POIDS_MAX=10

print("tri par VALEUR")
print(glouton_avec_critere() )
print('\n')
print("tri par VALEUR MASSIQUE")
print(glouton_avec_critere())

# %% [markdown]
# En modifiant si besoin la liste des objets, trouver un exemple pour lequel
# - le tri par VALEUR MASSIQUE donne une solution meilleur que le tri par VALEUR

# %%
objlist = [('Antidote', 3, 0.5), 
           ('Baguette magique', 5,1), 
           ('Cape d\'invisibilité', 12,1), 
           ('Diadème', 30,5), 
           ('Épée', 9,6), 
           ('Horloge', 10,5), 
           ('Miroir', 12,3)]
POIDS_MAX=10

...
