# %% [markdown]
# ## Exercice 9 p. 67

# %%
table1 = [('id_exp',  'T' , 'tps'),
          (    1   , 20.2 ,  56  ),
          (    2   , 15.5 ,  85  ),
          (    3   , 18.6 , 120  )]

# %%
table2 = [('id_exp',  'T' , 'tps'),
          (    1   , 53.6 , 210  ),
          (    2   , 62.6 ,  81  ),
          (    3   , 66.2 ,  70  )]

# %%
def fusion(t1,t2):
    """fusionne t1 et t2
    en renumérottant les expériences de t2
    et en convertissant les températures de t2 en degrés Celsius"""
    tab2 = [] 
    for i in range(1, len(t2)) : 
        F = t2[i][1]
        C = (F-32) / 1.8
        new = (100 + t2[i][0], C , t2[i][2] )
        tab2.append(new)
        #print (i , new, tab2)
    
    return t1 + tab2

# %%
fusion(table1, table2)
# Out:
# [('id_exp', 'T', 'tps'), (1, 20.2, 56), (2, 15.5, 85), (3, 18.6, 120), (101, 12.0, 210), (102, 17.0, 81), (103, 19.0, 70)]

# %%
def fusion(t1,t2):
    """fusionne t1 et t2
    en renumérottant les expériences de t2
    et en convertissant les températures de t2 en degrés Celsius"""
    tab2 = [] 
    for no, temp, tps in t2[1:] : 
        new = (no+100, (temp-32)/1.8, tps)
        tab2.append(new)
    
    return t1 + tab2

# %%
def fusion(t1,t2):
    """fusionne t1 et t2
    en renumérottant les expériences de t2
    et en convertissant les températures de t2 en degrés Celsius"""    
    return t1 + [  (no+100, (temp-32)/1.8, tps)  for no, temp, tps in t2[1:]]

# %%
fusion(table1, table2)
# Out:
# [('id_exp', 'T', 'tps'), (1, 20.2, 56), (2, 15.5, 85), (3, 18.6, 120), (101, 12.0, 210), (102, 17.0, 81), (103, 19.0, 70)]
