# %% [markdown]
# # Mini-projet : jeu de cartes
# * 3 groupes pour l'ensemble du projet
# * chaque groupe réalise :
#    1. une partie du **code** du projet (10 points)
#    2. une présentation **orale** (5 points)
#    3. un **document d'explication** à remettre sous forme papier ou numérique  (5 points) => au plus tard le 31 déc !
#
#
# Chaque partie du projet pourra utiliser le code fourni, pour afficher le jeu (version pour Windows [ici](proj2.py)).

# %%
NOIR = '\033[1;30;47m'
ROUGE = '\033[1;31;47m'
BLEU = '\033[1;34;47m'
DEFAULT = '\033[0m'

dico_couleur = {'Pique' : '\u2660' , 'Coeur': '\u2665', 'Carreau' : '\u2666' , 'Trèfle' : '\u2663', 'A':'a', 'B':'b', 'C':'c', 'D':'d'}
dico_valeur = { i : ' '+str(i)  for i in range(2,10)}
dico_valeur[10]='10'
dico_valeur[0]=' ?'

def valeur(carte):
    return carte[0]
def couleur(carte):
    return carte[1]

def aff_carte(carte):
    print(dico_valeur[valeur(carte)]+dico_couleur[couleur(carte)], end=' ')

def aff_carte_couleur(carte):
    if carte[0] == 0:
        print(BLEU+dico_valeur[valeur(carte)]+dico_couleur[couleur(carte)], end='')
    elif carte[1] in ('Coeur', 'Carreau'):
        print(ROUGE+dico_valeur[valeur(carte)]+dico_couleur[couleur(carte)], end='')
    else :
        print(NOIR+dico_valeur[valeur(carte)]+dico_couleur[couleur(carte)], end='')

def affiche_simple(tab):
    for i in range(4) :
        for j in range(10) :
            carte = tab[i][j]
            aff_carte(carte)
        print()
    print()

def affiche_couleur(tab):
    line = (NOIR+'   '+DEFAULT+' ')*10
    for i in range(4) :
        #print(line)
        for j in range(10) :
            carte = tab[i][j]
            aff_carte_couleur(carte)
            print(DEFAULT+' ', end='')
        print()
        #print(line)
        print()
    print()

def affiche(tab, color = False):
    if color : 
        affiche_couleur(tab)
    else :
        affiche_simple(tab)
    
t1 = [[(7, 'Coeur'), (10, 'Trèfle'), (6, 'Trèfle'), (7, 'Pique'), (4, 'Carreau'), (5, 'Coeur'), (2, 'Coeur'), (3, 'Coeur'), (6, 'Coeur'), (0, 'A')], 
      [(7, 'Carreau'), (6, 'Carreau'), (8, 'Trèfle'), (3, 'Trèfle'), (8, 'Coeur'), (6, 'Pique'), (3, 'Pique'), (8, 'Pique'), (2, 'Trèfle'), (0, 'B')], 
      [(3, 'Carreau'), (9, 'Pique'), (7, 'Trèfle'), (4, 'Coeur'), (10, 'Coeur'), (2, 'Pique'), (10, 'Carreau'), (10, 'Pique'), (9, 'Trèfle'), (0, 'C')], 
      [(8, 'Carreau'), (4, 'Pique'), (5, 'Trèfle'), (2, 'Carreau'), (4, 'Trèfle'), (5, 'Pique'), (5, 'Carreau'), (9, 'Coeur'), (9, 'Carreau'), (0, 'D')]]

t2 = [[(10, 'Pique'), (9, 'Pique'), (8, 'Pique'), (7, 'Trèfle'), (6, 'Trèfle'), (5, 'Trèfle'), (4, 'Trèfle'), (3, 'Trèfle'), (2, 'Trèfle'), (3, 'Carreau')], 
      [(10, 'Trèfle'), (2, 'Coeur'), (8, 'Trèfle'), (2, 'Pique'), (3, 'Coeur'), (2, 'Carreau'), (0, 'A'), (0, 'C'), (0, 'B'), (0, 'D')], 
      [(10, 'Carreau'), (9, 'Carreau'), (8, 'Carreau'), (3, 'Pique'), (6, 'Pique'), (5, 'Pique'), (4, 'Pique'), (9, 'Trèfle'), (5, 'Carreau'), (4, 'Carreau')], 
      [(10, 'Coeur'), (9, 'Coeur'), (8, 'Coeur'), (7, 'Coeur'), (6, 'Coeur'), (5, 'Coeur'), (4, 'Coeur'), (7, 'Carreau'), (6, 'Carreau'), (7, 'Pique')]]

# %%
carte = (7, 'Coeur')

# %%
valeur(carte)

# %%
couleur(carte)

# %%
aff_carte((7, 'Coeur'))

# %%
aff_carte_couleur((7, 'Coeur'))

# %%
t1

# %%
affiche(t1)

# %%
affiche(t1, color=True)

# %%
affiche(t2)

# %%
affiche(t2, color=True)

# %% [markdown]
# Il y a trois parties dans le projet.
#
# #### partie A : préparation du jeu, distribution des cartes.
#
# #### partie B : fonctions pour le joueur
#
# #### partie C : lorsque le jeu est bloqué... calcul du score, et ramassage des cartes mal rangées.

# %% [markdown]
# ## Partie A

# %% [markdown]
# Cette partie devra programmer les fonctions utiles pour :
# 1. générer un jeu de 36 cartes : du 10 au 2 pour chacune des couleurs 'Pique' , 'Coeur',  'Carreau' , 'Trèfle'.
#
# 2. obtenir un jeu mélangé  : on pourra utiliser la fonction `shuffle` du module `random` dont un exemple est donné ci-dessous
#
# 3. définir dans une variable **tablo** de type "liste de liste", l'équivalent du tableau `t1` du code fourni ci dessus, c'est à dire :
#    *  un tableau de longueur 4
#    * dont chaque item est lui-même un tableau de longueur 10
#    * dont la dernière cellule est l'une des "cartes inconnues" : `(0,'a'), (0,'b'), (0,'c'), (0'd')`.
#
# 4. définir une fonction **redistribue** qui
#    * prend deux paramètres :
#      * t : une liste de listes avec 4 lignes et 10 colonnes
#      * paquet : une liste de cartes
#    * on suppose que chaque  item de t est :
#      * soit une carte (valeur, couleur)
#      * soit None
#    * une fois exécutée la commande redistribue(t, paquet),
#      * chaque carte de t est inchangée
#      * le dernier item de chaque ligne de t est l'une des "cases libres" : `(0,'a'), (0,'b'), (0,'c'), (0'd')`.
#      * tous les autres items du tableau t qui valaient None ont été remplacés par une carte du paquet, choisie "au hasard".

# %% [markdown]
# #### aide pour le 2)
# exemple d'utilisation de `shuffle`

# %%
from random import shuffle
t = [10,20,30,40,50]

# %%
shuffle(t)
print(t)

# %%
shuffle(t)
print(t)

# %% [markdown]
# #### aide pour le 4
# exemple de tableau `t` et de liste `paquet`

# %%
affiche(t2, color=True)

# %% [markdown]
# En fin de partie, les cartes bien rangées sont laissée en place, et les autres sont ramassées dans un paquet.
# La fonction **redistribue** doit redistribuer les cartes du paquet dans le tableau, après avoir "mélangé" le paquet.

# %%
t = [[(10, 'Pique'), (9, 'Pique'), (8, 'Pique'), None, None, None, None, None, None, None], 
     [(10, 'Trèfle'), None, None, None, None, None, None, None, None, None], 
     [(10, 'Carreau'), (9, 'Carreau'), (8, 'Carreau'), None, None, None, None, None, None, None], 
     [(10, 'Coeur'), (9, 'Coeur'), (8, 'Coeur'), (7, 'Coeur'), (6, 'Coeur'), (5, 'Coeur'), (4, 'Coeur'), None, None, None]]

paquet = [(7, 'Trèfle'), (6, 'Trèfle'), (5, 'Trèfle'), (4, 'Trèfle'), (3, 'Trèfle'), (2, 'Trèfle'), (3, 'Carreau'), (2, 'Coeur'), (8, 'Trèfle'), (2, 'Pique'), (3, 'Coeur'), (2, 'Carreau'), (3, 'Pique'), (6, 'Pique'), (5, 'Pique'), (4, 'Pique'), (9, 'Trèfle'), (5, 'Carreau'), (4, 'Carreau'), (7, 'Carreau'), (6, 'Carreau'), (7, 'Pique')]

# %% [markdown]
# ## Partie B

# %% [markdown]
# Toutes cette partie suppose qu'une variable de type liste de liste représente l'état courant du jeu.
# On travaillera pour commencer avec le tableau `t1` donné dans le code précédent, qui représentera l'été initial du jeu.

# %%
affiche(t1, color=True)

# %% [markdown]
# La **partie B** doit programmer les fonctions utiles au joueur :
# 1. Une fonction permettant au joueur de choisir l'une des "cases" ?a, ?b, ?c, ?d.
# 2. Une fonction qui recherche la carte pouvant aller dans cette case.
# 3. Une fonction qui permet à l'utilisateur de choisir la carte qu'il veut déplacer, lorsque la "case vide" se trouve dans la première colonne du tableau (normalement, la carte choisie pour aller dans la première colonne est un 10).
# 4. Une fonction qui modifie le tableau de jeu, en échangeant la carte choisie par le joueur avec la case vide correcte.
# 5. Une fonction qui permet un "tour de jeu" complet avec :
#    * choix d'une case,
#    * déplacement de la carte correcte,
#    * affichage du nouvel état du jeu.

# %% [markdown]
# ## Partie C

# %% [markdown]
# Toutes cette partie suppose qu'une variable de type liste de liste représente l'état courant du jeu, alors que le joueur ne peut plus choisir de nouveau coup : "jeu bloqué".
# On travaillera avec le tableau `t2` donné dans le code précédent, qui représentera l'été final d'une partie du jeu.

# %%
affiche(t2, color=True)

# %% [markdown]
# La **partie C** doit programmer les fonctions utiles pour gérer la fin d'une partie du jeu :
# 1. Une fonction qui compte le nombre de cartes "bien rangées" dans le jeu. Une carte bien rangée est :
#    * soit un '10' rangé dans la première colonne
#    * soit une carte de la même couleur qu'une carte bien rangée, avec une valeur immédiatement inférieure. (dans l'exemple, la première ligne compte 3 cartes bien rangées).
# 2. Une fonction qui :
#    * affiche le score du jeu, c'est à dire le nombre de cartes bien rangées, puis
#    * demande à l'utilisateur s'il souhaite ramasser les cartes mal rangées pour les redistribuer.
#    * cette fonction doit renvoyer `True` ou `False`, selon la réponse du joueur.
# 3. Une fonction qui "ramasse" les cartes mal rangées, c'est à dire :
#    * qui renvoie la liste des cartes qui étaient mal rangées dans le jeu. On nommera cette liste : `paquet`.
#    * la fonction "ramasse" doit modifier le tableau de jeu, de sorte que :
#       * chaque carte bien rangée soit laissée à sa place
#       * chaque carte "mal rangée" soit remplacée par `None`
#       * les "cases vides" ?a, ?b, ?c, ?d seront remplacées par `None`, mais ne seront pas incluses dans le `paquet` renvoyé par la fonction

# %% [markdown]
# #### aide pour le 3
# on pourra vérifier que la fonction "ramasse" appliquée au tableau t2 renvoie le "paquet" suivant :
#
#     [(7, 'Trèfle'), (6, 'Trèfle'), (5, 'Trèfle'), (4, 'Trèfle'), (3, 'Trèfle'), (2, 'Trèfle'), (3, 'Carreau'), (2, 'Coeur'), (8, 'Trèfle'), (2, 'Pique'), (3, 'Coeur'), (2, 'Carreau'), (3, 'Pique'), (6, 'Pique'), (5, 'Pique'), (4, 'Pique'), (9, 'Trèfle'), (5, 'Carreau'), (4, 'Carreau'), (7, 'Carreau'), (6, 'Carreau'), (7, 'Pique')]
#
# Une fois exécutée cette fonction, le tableau t2 doit contenir les valeurs suivantes :
#
#     [[(10, 'Pique'), (9, 'Pique'), (8, 'Pique'), None, None, None, None, None, None, None],
#     [(10, 'Trèfle'), None, None, None, None, None, None, None, None, None],
#     [(10, 'Carreau'), (9, 'Carreau'), (8, 'Carreau'), None, None, None, None, None, None, None],
#     [(10, 'Coeur'), (9, 'Coeur'), (8, 'Coeur'), (7, 'Coeur'), (6, 'Coeur'), (5, 'Coeur'), (4, 'Coeur'), None, None, None]]
